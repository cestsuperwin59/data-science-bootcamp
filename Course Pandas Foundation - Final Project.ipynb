# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 19 July 2023
#
# **Author**: Thongpan Leangapichart
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd

df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# example of pd.to_datetime() function
df['ORD'] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df['SHD'] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>ORD</th>
#       <th>SHD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - count nan in postal code column
df['Postal Code'].isna().sum()
# Out:
# 11

# %%
# TODO - filter rows with missing values

filter_data = df.dropna().reset_index(drop=True)
filter_data.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>ORD</th>
#       <th>SHD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions
df.groupby(['Region', 'Category'])['Quantity'].sum().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Region</th>
#       <th>Category</th>
#       <th>Quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Central</td>
#       <td>Furniture</td>
#       <td>1827</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Central</td>
#       <td>Office Supplies</td>
#       <td>5409</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Central</td>
#       <td>Technology</td>
#       <td>1544</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>East</td>
#       <td>Furniture</td>
#       <td>2214</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset. Ans. 9994 rows and 23 columns
df.shape
# Out:
# (9994, 23)

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?. Ans Postal Code has 11 missing values
df.isna().sum()
# Out:
# <pre>Row ID             0
# Order ID           0
# Order Date         0
# Ship Date          0
# Ship Mode          0
# Customer ID        0
# Customer Name      0
# Segment            0
# Country/Region     0
# City               0
# State              0
# Postal Code       11
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales              0
# Quantity           0
# Discount           0
# Profit             0
# ORD                0
# SHD                0
# dtype: int64</pre>

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
filter_california = df[(df['State'] == 'California')]
filter_california.to_csv('california.csv')

filter_california
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>ORD</th>
#       <th>SHD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
# ...

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file

df['ORD_YEAR'] = pd.to_datetime(df['ORD']).dt.strftime('%Y')

filter_cali_tex17 = df[((df['State'] == 'California') | (df['State'] == 'Texas')) & (df['ORD_YEAR'] == '2017')]
filter_cali_tex17.to_csv('filter_cali_tex17.csv')

filter_cali_tex17
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>ORD</th>
#       <th>SHD</th>
#       <th>ORD_YEAR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
#       <td>6</td>
# ...

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017

df_2017 = df[df['ORD_YEAR'] == '2017']
order_2017 = df_2017['Sales'].agg(['sum','std','mean'])
order_2017
# Out:
# <pre>sum     484247.498100
# std        754.053357
# mean       242.974159
# Name: Sales, dtype: float64</pre>

# %%
# TODO 06 - which Segment has the highest profit in 2018
df_2018 = df[df['ORD_YEAR'] == '2018']

check_profit_2018 = df_2018[['Segment', 'Profit']].groupby('Segment').sum().reset_index()

check_profit_2018.head(1)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Segment</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Consumer</td>
#       <td>28460.1665</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019

df_apr_dec2019 = df[(df['ORD'] >= '2019-04-15') & (df['ORD'] <= '2019-12-31')]
leastsales_states_2019 = df_apr_dec2019[['State', 'Sales']].groupby('State').sum().sort_values('Sales', ascending=True)
print(leastsales_states_2019.head(5).reset_index())
# Out:
#                   State   Sales
# 0         New Hampshire   49.05
# 1            New Mexico   64.08
# 2  District of Columbia  117.07
# 3             Louisiana  249.80
# 4        South Carolina  502.48

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25% 
df_2019 = df[df['ORD_YEAR'] == '2019']

result_2019 = df_2019['Sales'].sum()
wc_sales = df_2019[(df_2019['Region'] == 'West') | (df_2019['Region'] == 'Central')]['Sales'].sum()

proportion = (wc_sales/result_2019*100).round(2)

print(f"West + Central Sales  {proportion}%  in 2019")
# Out:
# West + Central Sales  54.97%  in 2019

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

df_2019_20 = df[(df['ORD_YEAR'] == '2019') | (df['ORD_YEAR'] == '2020')].reset_index()

top10_sales = df_2019_20.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).reset_index().head(10)
top10_order = df_2019_20.groupby('Product Name')['Order ID'].count().sort_values(ascending=False).reset_index().head(10)


print(top10_sales)
print(top10_order)
# Out:
#                                         Product Name      Sales
# 0              Canon imageCLASS 2200 Advanced Copier  61599.824
# 1               Hewlett Packard LaserJet 3310 Copier  16079.732
# 2   3D Systems Cube Printer, 2nd Generation, Magenta  14299.890
# 3   GBC Ibimaster 500 Manual ProClick Binding System  13621.542
# 4         GBC DocuBind TL300 Electric Binding System  12737.258
# 5          GBC DocuBind P400 Electric Binding System  12521.108
# 6                            Samsung Galaxy Mega 6.3  12263.708
# 7       HON 5400 Series Task Chairs for Big and Tall  11846.562
# 8  Martin Yale Chadless Opener Electric Letter Op...  11825.902
# 9      Global Troy Executive Leather Low-Back Tilter  10169.894
#                                       Product Name  Order ID
# 0                                Easy-staple paper        27
# 1                                          Staples        24
# 2                                  Staple envelope        22
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

df_2019_20.groupby('Sub-Category')['Sales'].sum().plot(kind = 'bar')

df_2019_20.plot(x = 'Sales', y = 'Profit', kind = 'scatter', color='orange');

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions

import numpy as np

df_2019_20['Huge profit'] = np.where(df_2019_20['Profit']> 100, True, False)

df_2019_20.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>index</th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>...</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#       <th>ORD</th>
#       <th>SHD</th>
#       <th>ORD_YEAR</th>
#       <th>Huge profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...
