# %% [markdown]
# <a href="https://colab.research.google.com/github/cestsuperwin59/data-science-bootcamp/blob/main/data_quality_class_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown
import pandas as pd
import numpy as np
import os
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
import logging
from datetime import date, timedelta
import datetime
import re

# %%
url = "https://drive.google.com/drive/folders/10nDN6hzhussHBOYrkyCfzOp0dCJjDJnq?usp=sharing"
gdown.download_folder(url, quiet=True, use_cookies=False)
# Out:
# ['/content/data_quality_rk_clss/book_master_2023-03-24.csv']

# %%
#https://medium.com/analytics-vidhya/how-to-connect-google-drive-to-python-using-pydrive-9681b2a14f20
# https://pythonhosted.org/PyDrive/oauth.html#authentication-in-two-lines
# gauth = GoogleAuth()
# Create local webserver and auto handles authentication.
# gauth.LocalWebserverAuth()

# %% [markdown]
# # **** Data Transformation Part ****

# %%
# https://www.w3schools.com/python/python_datetime.asp

today=date.today().strftime("%Y-%m-%d") #2022-10-29

yesterday=date.today()- datetime.timedelta(days=1)

yesterday=yesterday.strftime("%Y-%m-%d")

designatedFileName='book_master_'+yesterday+'.csv' # to fix this
# designatedFileName='book_master_2023-03-24.csv' # hardcode

print(designatedFileName)
# Out:
# book_master_2023-08-19.csv

# %%
# https://docs.python.org/3/library/logging.html
log_file_name=today+'_log.log'

logging.basicConfig(filename=log_file_name,
                    format='%(asctime)s %(message)s',
                    filemode='w',level=logging.INFO)

logger = logging.getLogger()

# %%
df=pd.read_csv(f'data_quality_rk_clss/{designatedFileName}')
df.tail(3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-4fb1be8e20be> in <cell line: 1>()
# ----> 1 df=pd.read_csv(f'data_quality_rk_clss/{designatedFileName}')
#       2 df.tail(3)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_quality_rk_clss/book_master_2023-08-19.csv'

# %%
# file_list = drive.ListFile({'q': "'1tq2wthWD_eFpuT_cJwLs4rxDs0h1OfBd' in parents and trashed=false"}).GetList()
# file_df=pd.DataFrame(file_list)

#Check if the file is existed

# file_df[file_df.title==designatedFileName]['id'].values[0]

# if(file_df[file_df.title==designatedFileName].shape[0]!=0):
#     print(f'{designatedFileName}` detected')
#     logger.info(f'`{designatedFileName}` detected')
# else:
#     logger.error(f'`{designatedFileName}` was not found')
#     raise ImportError(f'`{designatedFileName}` was not found')

# %%
# # https://pythonhosted.org/PyDrive/filemanagement.html#download-file-content

# designatedID=file_df[file_df.title==designatedFileName]['id'].values[0]
# tmpFileName='tmp_'+designatedFileName
# drive.CreateFile({'id': designatedID}).GetContentFile(tmpFileName)
# df=pd.read_csv(tmpFileName)

# %% [markdown]
# ## 1. REMOVE QUANTITY <=0

# %%
#create df that has no quantity<=0
df=df[df.Quantity>0]

# %%
df[df.Quantity==0]
# Out:
# Empty DataFrame
# Columns: [book_id, Title, Book_category, Star_rating, Price, Stock, Quantity, user_input, สำนักพิมพ์, PublishedDate, add_date]
# Index: []

# %%
df[['Title']][df.Quantity==0]
# Out:
#                                           Title
# 892                          The Course of Love
# 895  Run, Spot, Run: The Ethics of Keeping Pets
# 896                      New Moon (Twilight #2)
# 898              Kindle Paperwhite User's Guide
# 899                               H is for Hawk

# %% [markdown]
# ## 2. QC book title can't have multiple rows

# %%
#group by book title and count row
df.groupby('Title').count()
g = df.groupby('Title').count()
g
# Out:
#                                                     book_id  Book_category  \
# Title
# "Most Blessed of the Patriarchs": Thomas Jeffer...        1              1
# #GIRLBOSS                                                 1              1
# #HigherSelfie: Wake Up Your Life. Free Your Sou...        1              1
# 'Salem's Lot                                              1              1
# (Un)Qualified: How God Uses Broken People to Do...        1              1
# ...                                                     ...            ...
# Zealot: The Life and Times of Jesus of Nazareth           1              1
# Zero History (Blue Ant #3)                                1              1
# Zero to One: Notes on Startups, or How to Build...        1              1
# orange: The Complete Collection 1 (orange: The ...        1              1
# salt.                                                     1              1
#
#                                                     Star_rating  Price  Stock  \
# Title
# "Most Blessed of the Patriarchs": Thomas Jeffer...            1      1      1
# #GIRLBOSS                                                     1      1      1
# #HigherSelfie: Wake Up Your Life. Free Your Sou...            1      1      1
# 'Salem's Lot                                                  1      1      1
# (Un)Qualified: How God Uses Broken People to Do...            1      1      1
# ...                                                         ...    ...    ...
# Zealot: The Life and Times of Jesus of Nazareth               1      1      1
# Zero History (Blue Ant #3)                                    1      1      1
# Zero to One: Notes on Startups, or How to Build...            1      1      1
# orange: The Complete Collection 1 (orange: The ...            1      1      1
# salt.                                                         1      1      1
#
#                                                     Quantity  user_input  \
# Title
# "Most Blessed of the Patriarchs": Thomas Jeffer...         1           1
# #GIRLBOSS                                                  1           1
# #HigherSelfie: Wake Up Your Life. Free Your Sou...         1           1
# 'Salem's Lot                                               1           1
# (Un)Qualified: How God Uses Broken People to Do...         1           1
# ...                                                      ...         ...
# Zealot: The Life and Times of Jesus of Nazareth            1           1
# Zero History (Blue Ant #3)                                 1           1
# Zero to One: Notes on Startups, or How to Build...         1           1
# orange: The Complete Collection 1 (orange: The ...         1           1
# salt.                                                      1           1
#
#                                                     สำนักพิมพ์  PublishedDate  \
# Title
# "Most Blessed of the Patriarchs": Thomas Jeffer...           1              1
# #GIRLBOSS                                                    1              1
# #HigherSelfie: Wake Up Your Life. Free Your Sou...           1              1
# 'Salem's Lot                                                 1              1
# (Un)Qualified: How God Uses Broken People to Do...           1              1
# ...                                                        ...            ...
# Zealot: The Life and Times of Jesus of Nazareth              1              1
# Zero History (Blue Ant #3)                                   1              1
# Zero to One: Notes on Startups, or How to Build...           1              1
# orange: The Complete Collection 1 (orange: The ...           1              1
# salt.                                                        1              1
#
#                                                     add_date
# Title
# "Most Blessed of the Patriarchs": Thomas Jeffer...         0
# #GIRLBOSS                                                  0
# #HigherSelfie: Wake Up Your Life. Free Your Sou...         0
# 'Salem's Lot                                               0
# (Un)Qualified: How God Uses Broken People to Do...         0
# ...                                                      ...
# Zealot: The Life and Times of Jesus of Nazareth            0
# Zero History (Blue Ant #3)                                 0
# Zero to One: Notes on Startups, or How to Build...         0
# orange: The Complete Collection 1 (orange: The ...         0
# salt.                                                      0
#
# [994 rows x 10 columns]

# %%
# g[g.Book_category>1]
g[g['Book_category']>1]
# Out:
#                                                     book_id  Book_category  \
# Title
# America's War for the Greater Middle East: A Mi...        2              2
# The Star-Touched Queen                                    2              2
#
#                                                     Star_rating  Price  Stock  \
# Title
# America's War for the Greater Middle East: A Mi...            2      2      2
# The Star-Touched Queen                                        2      2      2
#
#                                                     Quantity  user_input  \
# Title
# America's War for the Greater Middle East: A Mi...         2           2
# The Star-Touched Queen                                     2           2
#
#                                                     สำนักพิมพ์  PublishedDate  \
# Title
# America's War for the Greater Middle East: A Mi...           2              2
# The Star-Touched Queen                                       2              2
#
#                                                     add_date
# Title
# America's War for the Greater Middle East: A Mi...         0
# The Star-Touched Queen                                     0

# %%
g[g['Book_category']>1].index.tolist()
# Out:
# ["America's War for the Greater Middle East: A Military History",
#  'The Star-Touched Queen']

# %%
#add dup title to dup_title
dup_title = g[g['Book_category']>1].index.tolist()
dup_title
# Out:
# ["America's War for the Greater Middle East: A Military History",
#  'The Star-Touched Queen']

# %%
df[df.Title.isin(dup_title)]
# Out:
#       book_id                                              Title  \
# 0        3000                               A Light in the Attic
# 1        3001                                 Tipping the Velvet
# 2        3002                                         Soumission
# 3        3003                                      Sharp Objects
# 4        3004              Sapiens: A Brief History of Humankind
# ...       ...                                                ...
# 996      3996  Alice in Wonderland (Alice's Adventures in Won...
# 997      3997   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity  user_input  \
# 0                 Poetry       Three  51.77  In stock        22   M.Bridges
# 1     Historical Fiction         One  53.74  In stock        20   E. Barron
# 2                Fiction         One  50.10  In stock        20   E. Barron
# 3                Mystery        Four  47.82  In stock        20   E. Barron
# 4                History        Five  54.23  In stock        20   E. Barron
# ...                  ...         ...    ...       ...       ...         ...
# 996             Classics         One  55.53  In stock         1   E. Barron
# 997       Sequential Art        Four  57.06  In stock         1   E. Barron
# 998   Historical Fiction        Five  16.97  In stock         1  A. Edwards
# 999              Mystery         One  53.98  In stock         1  A. Edwards
# 1000              Travel        Five  26.08  In stock         1   E. Barron
#
#        สำนักพิมพ์ PublishedDate  add_date
# 0     Dragonsteel    2022-09-25       NaN
# 1     Dragonsteel    2022-09-25       NaN
# 2             TOR    2022-09-25       NaN
# 3     Dragonsteel    2022-09-25       NaN
# 4     Dragonsteel    2022-09-25       NaN
# ...           ...           ...       ...
# 996   Dragonsteel    2022-09-25       NaN
# 997     O' Reilly    2022-09-25       NaN
# 998   Dragonsteel    2022-09-25       NaN
# 999     O' Reilly    2022-09-25       NaN
# 1000    O' Reilly    2022-09-25       NaN
#
# [992 rows x 11 columns]

# %%
#remove title which has multiple rows (by randomly)
df=df.drop_duplicates(subset=['Title'])

# %%
df[df.Title.isin(dup_title)]
# Out:
#      book_id                                              Title Book_category  \
# 236     3236                             The Star-Touched Queen       Fantasy
# 639     3639  America's War for the Greater Middle East: A M...       History
#
#     Star_rating  Price     Stock  Quantity user_input   สำนักพิมพ์  \
# 236        Five  46.02  In stock        14  E. Barron    O' Reilly
# 639         Two  51.22  In stock         4  M.Bridges  Dragonsteel
#
#     PublishedDate  add_date
# 236    2022-09-25       NaN
# 639    2022-09-24       NaN

# %% [markdown]
# ## 3. Rename Thai column

# %%
df.tail(3)
# Out:
#       book_id                                              Title  \
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity  user_input  \
# 998   Historical Fiction        Five  16.97  In stock         1  A. Edwards
# 999              Mystery         One  53.98  In stock         1  A. Edwards
# 1000              Travel        Five  26.08  In stock         1   E. Barron
#
#        สำนักพิมพ์ PublishedDate  add_date
# 998   Dragonsteel    2022-09-25       NaN
# 999     O' Reilly    2022-09-25       NaN
# 1000    O' Reilly    2022-09-25       NaN

# %%
#rename สำนักพิมพ์ to Publisher

df.rename(columns = {'สำนักพิมพ์':'Publisher'}, inplace = True)
# df=df.rename(columns = {'สำนักพิมพ์':'Publisher'})
df.tail(3)
# Out:
#       book_id                                              Title  \
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity  user_input  \
# 998   Historical Fiction        Five  16.97  In stock         1  A. Edwards
# 999              Mystery         One  53.98  In stock         1  A. Edwards
# 1000              Travel        Five  26.08  In stock         1   E. Barron
#
#         Publisher PublishedDate  add_date
# 998   Dragonsteel    2022-09-25       NaN
# 999     O' Reilly    2022-09-25       NaN
# 1000    O' Reilly    2022-09-25       NaN

# %% [markdown]
# ## 4. Amend Thai value inside the cell to English

# %%
df.Book_category.value_counts()
# Out:
# Default               152
# Nonfiction            108
# Sequential Art         75
# Add a comment          67
# Fiction                64
# Young Adult            48
# Fantasy                47
# Romance                35
# Mystery                32
# Food and Drink         30
# Childrens              29
# Historical Fiction     26
# Classics               19
# Poetry                 18
# History                18
# Horror                 17
# Womens Fiction         17
# Science Fiction        16
# Science                14
# Music                  13
# Business               12
# Thriller               11
# Travel                 11
# Humor                  10
# Philosophy             10
# Autobiography           9
# Art                     8
# Psychology              7
# Religion                7
# Spirituality            6
# Christian Fiction       6
# New Adult               6
# Sports and Games        5
# YA                      5
# Biography               5
# Self Help               5
# Health                  4
# Contemporary            3
# Politics                3
# Christian               3
# Historical              2
# Crime                   1
# Parenting               1
# Adult Fiction           1
# กวี                     1
# Academic                1
# Novels                  1
# Suspense                1
# Short Stories           1
# Cultural                1
# Erotica                 1
# Paranormal              1
# Name: Book_category, dtype: int64

# %%
df[df.Book_category=='กวี']
#df.loc[df.Book_category=='กวี']
# Out:
#     book_id                           Title Book_category Star_rating  Price  \
# 40     3040  Slow States of Collapse: Poems           กวี       Three  57.31
#
#        Stock  Quantity  user_input    Publisher PublishedDate  add_date
# 40  In stock        17  A. Edwards  Dragonsteel    2022-09-25       NaN

# %%
#change row that has [กวี] value to [Poetry] value
df['Book_category']=np.where(df.Book_category=='กวี', 'Poetry', df.Book_category)

# %%
#check result
df.loc[df.book_id==3040]
# Out:
#     book_id                           Title Book_category Star_rating  Price  \
# 40     3040  Slow States of Collapse: Poems        Poetry       Three  57.31
#
#        Stock  Quantity  user_input    Publisher PublishedDate  add_date
# 40  In stock        17  A. Edwards  Dragonsteel    2022-09-25       NaN

# %% [markdown]
# ## 5. Create column: [import_date] = [today] value

# %%
# set import_date = today
df['import_date']=today
df.tail()
# Out:
#       book_id                                              Title  \
# 996      3996  Alice in Wonderland (Alice's Adventures in Won...
# 997      3997   Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity  user_input  \
# 996             Classics         One  55.53  In stock         1   E. Barron
# 997       Sequential Art        Four  57.06  In stock         1   E. Barron
# 998   Historical Fiction        Five  16.97  In stock         1  A. Edwards
# 999              Mystery         One  53.98  In stock         1  A. Edwards
# 1000              Travel        Five  26.08  In stock         1   E. Barron
#
#         Publisher PublishedDate  add_date import_date
# 996   Dragonsteel    2022-09-25       NaN  2023-03-25
# 997     O' Reilly    2022-09-25       NaN  2023-03-25
# 998   Dragonsteel    2022-09-25       NaN  2023-03-25
# 999     O' Reilly    2022-09-25       NaN  2023-03-25
# 1000    O' Reilly    2022-09-25       NaN  2023-03-25

# %%
df['import_date'].unique()
# Out:
# array(['2023-03-25'], dtype=object)

# %% [markdown]
# ## 6. check date column to [YYYY-MM-DD] date format DD/MM/YYYY e.g. 25/09/2022 to 2022-09-25

# %%
#see this doc: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes

# %%
df.loc[df.book_id.isin([3665,3040])]
# Out:
#      book_id                           Title Book_category Star_rating  Price  \
# 40      3040  Slow States of Collapse: Poems        Poetry       Three  57.31
# 665     3665      No One Here Gets Out Alive         Music        Five  20.02
#
#         Stock  Quantity  user_input    Publisher PublishedDate  add_date  \
# 40   In stock        17  A. Edwards  Dragonsteel    2022-09-25       NaN
# 665  In stock         4   E. Barron          TOR    25/09/2022       NaN
#
#     import_date
# 40   2023-03-25
# 665  2023-03-25

# %%
#  2/2/2023 M D Y ? D M Y

25/9/2022
9/25/20222

# %%
#reformat [PublishedDate] with new column name: [PublishedDate_cleaned]
df['PublishedDate_cleaned']=pd.to_datetime(df['PublishedDate']).dt.strftime('%Y-%m-%d')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/core/tools/datetimes.py:1047: UserWarning: Parsing '25/09/2022' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)

# %%
df[['PublishedDate','PublishedDate_cleaned']].value_counts()
# Out:
# PublishedDate  PublishedDate_cleaned
# 2022-09-25     2022-09-25               984
# 2022-09-21     2022-09-21                 6
# 25/09/2022     2022-09-25                 3
# 2022-09-24     2022-09-24                 1
# dtype: int64

# %%
df.drop(columns='PublishedDate').head(2)
# Out:
#    book_id                 Title       Book_category Star_rating  Price  \
# 0     3000  A Light in the Attic              Poetry       Three  51.77
# 1     3001    Tipping the Velvet  Historical Fiction         One  53.74
#
#       Stock  Quantity user_input    Publisher  add_date import_date  \
# 0  In stock        22  M.Bridges  Dragonsteel       NaN  2023-03-25
# 1  In stock        20  E. Barron  Dragonsteel       NaN  2023-03-25
#
#   PublishedDate_cleaned
# 0            2022-09-25
# 1            2022-09-25

# %%
df.head()
# Out:
#    book_id                                  Title       Book_category  \
# 0     3000                   A Light in the Attic              Poetry
# 1     3001                     Tipping the Velvet  Historical Fiction
# 2     3002                             Soumission             Fiction
# 3     3003                          Sharp Objects             Mystery
# 4     3004  Sapiens: A Brief History of Humankind             History
#
#   Star_rating  Price     Stock  Quantity user_input    Publisher  \
# 0       Three  51.77  In stock        22  M.Bridges  Dragonsteel
# 1         One  53.74  In stock        20  E. Barron  Dragonsteel
# 2         One  50.10  In stock        20  E. Barron          TOR
# 3        Four  47.82  In stock        20  E. Barron  Dragonsteel
# 4        Five  54.23  In stock        20  E. Barron  Dragonsteel
#
#   PublishedDate  add_date import_date PublishedDate_cleaned
# 0    2022-09-25       NaN  2023-03-25            2022-09-25
# 1    2022-09-25       NaN  2023-03-25            2022-09-25
# 2    2022-09-25       NaN  2023-03-25            2022-09-25
# 3    2022-09-25       NaN  2023-03-25            2022-09-25
# 4    2022-09-25       NaN  2023-03-25            2022-09-25

# %%
# Drop column:[PublishedDate]
df.drop(columns='PublishedDate',inplace=True)
# df=df.drop(columns='PublishedDate')
# Rename [PublishedDate_cleaned] to [PublishedDate]
df.rename(columns = {'PublishedDate_cleaned':'PublishedDate'},inplace=True)

# %%
df.tail(3)
# Out:
#       book_id                                              Title  \
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity  user_input  \
# 998   Historical Fiction        Five  16.97  In stock         1  A. Edwards
# 999              Mystery         One  53.98  In stock         1  A. Edwards
# 1000              Travel        Five  26.08  In stock         1   E. Barron
#
#         Publisher  add_date import_date PublishedDate
# 998   Dragonsteel       NaN  2023-03-25    2022-09-25
# 999     O' Reilly       NaN  2023-03-25    2022-09-25
# 1000    O' Reilly       NaN  2023-03-25    2022-09-25

# %% [markdown]
# ## 7. Select certain columns

# %%
df.columns
# Out:
# Index(['book_id', 'Title', 'Book_category', 'Star_rating', 'Price', 'Stock',
#        'Quantity', 'user_input', 'Publisher', 'add_date', 'import_date',
#        'PublishedDate'],
#       dtype='object')

# %%
df=df[['book_id',
 'Title',
 'Book_category',
 'Star_rating',
 'Price',
 'Stock',
 'Quantity',
 'Publisher','PublishedDate','import_date']]

# %%
df.tail(3)
# Out:
#       book_id                                              Title  \
# 998      3998  A Spy's Devotion (The Regency Spies of London #1)
# 999      3999                1st to Die (Women's Murder Club #1)
# 1000     4000                 1,000 Places to See Before You Die
#
#            Book_category Star_rating  Price     Stock  Quantity    Publisher  \
# 998   Historical Fiction        Five  16.97  In stock         1  Dragonsteel
# 999              Mystery         One  53.98  In stock         1    O' Reilly
# 1000              Travel        Five  26.08  In stock         1    O' Reilly
#
#      PublishedDate import_date
# 998     2022-09-25  2023-03-25
# 999     2022-09-25  2023-03-25
# 1000    2022-09-25  2023-03-25

# %% [markdown]
#  ### ----- Transformation Part Completed -----

# %% [markdown]
# # **** Data Quality Part ****

# %% [markdown]
# ## 1.Check template column. Must be the same

# %%
template_col=['book_id','Title','Book_category','Star_rating','Price','Stock','Quantity','Publisher','PublishedDate','import_date']

# template_col

# %%
df.columns.tolist()
# Out:
# ['book_id',
#  'Title',
#  'Book_category',
#  'Star_rating',
#  'Price',
#  'Stock',
#  'Quantity',
#  'Publisher',
#  'PublishedDate',
#  'import_date']

# %%
if ((template_col==df.columns.tolist()))==False:

    logger.error("File columns don't match the current table format")
    logger.error(f"Unsuccessful:File columns don't match the current table format \n template: {template_col} \n csv file: {df.columns} ")
    raise ValueError(f"Unsuccessful:File columns don't match the current table format \n template: {template_col} \n csv file: {df.columns} ")

else:
    print('File columns match the current table format')
    logger.info('File columns match the current table format')
# Out:
# File columns match the current table format

# %% [markdown]
# 1.1 Check if there is quantity <=0

# %%
len(df[df.Quantity<=0])
# Out:
# 0

# %%
if (len(df[df.Quantity<=0])>1):
    raise ImportError(f'`{df}` quantity has <=0')
else:
    print('passs')
# Out:
# passs

# %% [markdown]
# ##  2. book title can't have multiple rows

# %%
g=df.groupby('Title').count()
g
if(len(g[g.Book_category>1]>1)):
    err_txt='Book_category>1 per title'
    logger.error(err_txt)
    raise ImportError(err_txt)
else:
    print('pass')
# Out:
# pass

# %% [markdown]
# ## 3. If import_date = today

# %%
# Out:
# True

# %%
pd.Series(df.import_date==today).all()==True
# Out:
# True

# %%
if(pd.Series(df.import_date==today).all()==False):

    raise ImportError('update date is not today')
else:
    print('pass')
# Out:
# pass

# %% [markdown]
# ## -------------- END --------------

# %% [markdown]
# ## Data Transformation + DQC were done, then what??

# %%
import push_to_db as pppp
ppp.push('sfsdgf')
